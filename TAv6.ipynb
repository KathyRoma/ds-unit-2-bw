# %%
import pandas as pd
import numpy as np

# %%
# I converted excel lists to csv and read them
scans = pd.read_csv('TraceAir - full_table.csv', header=1)

# %%
# I called my dataframe scans because tables contain information about scan characteristics
scans.head()
# Out:
#                     client              site        date accuracy cameras. m  \
# 0  independent-construction    russell-ranch  2018-07-03               10.00
# 1                 fivepoint  mission-village  2018-07-03               10.00
# 2  independent-construction          skyline  2018-07-05               10.00
# 3                   landsea        sanctuary  2018-07-03                   -
# 4  independent-construction    river-islands  2018-07-05                   -
#
#   Number of images Flying altitude Ground resolution Coverage area Tie points  \
# 0              714           167 m       7.11 cm/pix    0.924 km^2    1506410
# 1             2294           224 m       9.59 cm/pix     4.84 km^2    4208390
# 2             1292           254 m       11.1 cm/pix     2.36 km^2    2217947
# 3              222           125 m       3.59 cm/pix    0.315 km^2    1218819
# 4              944           146 m       6.13 cm/pix     1.68 km^2    3456900
#
# ...

# %%
# Let's see what do we have here
scans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 959 entries, 0 to 958
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   client                       959 non-null    object
#  1   site                         959 non-null    object
#  2   date                         959 non-null    object
#  3   accuracy cameras. m          959 non-null    object
#  4   Number of images             958 non-null    object
#  5   Flying altitude              959 non-null    object
#  6   Ground resolution            959 non-null    object
#  7   Coverage area                959 non-null    object
#  8   Tie points                   959 non-null    object
#  9   Projections                  959 non-null    object
#  10  Camera Model                 959 non-null    object
#  11  Resolution                   959 non-null    object
#  12  Pixel Size                   959 non-null    object
# ...

# %%
# My second csv is read prom another excel list
scans2 = pd.read_csv('TraceAir - qc.csv')

# %%
# We can see that the first three columns in both scans and scans2 identify one unique observation
# On a practical side it means that one scan is produces on a specific construction site any given date
scans2.head()
# Out:
#                      client             site date\r\nscans control photoscan  \
# 0  independent-construction    russell-ranch    2018-07-03               NaN
# 1                 fivepoint  mission-village    2018-07-03               NaN
# 2  independent-construction          skyline    2018-07-05               NaN
# 3                   landsea        sanctuary    2018-07-03               NaN
# 4  independent-construction    river-islands    2018-07-05               NaN
#
#   accuracy cameras     camera model   resolution number of photos  \
# 0            10.00  FC350 (3.61 mm)  4000 x 3000              714
# 1            10.00  FC350 (3.61 mm)  4000 x 3000             2294
# 2            10.00  FC350 (3.61 mm)  4000 x 3000             1292
# 3                -  FC6310 (8.8 mm)  4864 x 3648              222
# 4                -  FC350 (3.61 mm)  4000 x 3000              944
#
#   Average camera location error, cm fact accuracy in photoscans,cm  \
# ...

# %%
# scans2 contains different information about same scans
# There's a faid deal of missing values, 
# And not a single numeric value? Let's have a closer look why is that so
scans2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   client                             959 non-null    object
#  1   site                               959 non-null    object
#  2   date
# scans                        959 non-null    object
#  3   control photoscan                  788 non-null    object
#  4   accuracy cameras                   945 non-null    object
#  5   camera model                       959 non-null    object
#  6   resolution                         959 non-null    object
#  7   number of photos                   957 non-null    object
#  8   Average camera location error, cm  959 non-null    object
#  9   fact accuracy in photoscans,cm     959 non-null    object
#  10  image overlap                      767 non-null    object
# ...

# %%
# My two datasets are of a slightly different shape
scans.shape
# Out:
# (959, 39)

# %%
# The second one contains more observations
scans2.shape
# Out:
# (1055, 17)

# %%
# I need to get column names for further manipulations with my datasets
scans.columns
# Out:
# Index(['client ', 'site', 'date', 'accuracy cameras. m', 'Number of images',
#        'Flying altitude', 'Ground resolution', 'Coverage area', 'Tie points',
#        'Projections', 'Camera Model', 'Resolution', 'Pixel Size',
#        'Precalibrated', 'Type', 'Total (cm)', 'Matching time',
#        'Alignment time', 'X error (cm)', 'Y error (cm)', 'Z error (cm)',
#        'XY error (cm)', 'Total (cm).1', 'Resolution.1', 'Point density',
#        'Coordinate system', 'Rotation angles', 'RMS reprojection error',
#        'Max reprojection error', 'Mean key point size', 'Effective overlap',
#        'Accuracy', 'Generic preselection', 'Reference preselection',
#        'Key point limit', 'Tie point limit', 'Optimization time',
#        'Depth maps generation time', 'Dense cloud generation time'],
#       dtype='object')

# %%
scans2.columns
# Out:
# Index(['client', 'site', 'date\r\nscans', 'control photoscan',
#        'accuracy cameras', 'camera model', 'resolution', 'number of photos',
#        'Average camera location error, cm', 'fact accuracy in photoscans,cm',
#        'image overlap', 'fractional dem-diff', 'fractional dd colours',
#        'volume control', 'monitoring area', 'result', 'Unnamed: 16'],
#       dtype='object')

# %%
# First catch -- 'client ' column in the first dataset needs a strip
scans.columns = scans.columns.str.strip()

# %%
# Then, I rename the column with date in the second set, making sure it's identical to 'date' from scans dataframe
scans2.rename(columns = {'date\r\nscans':'date'}, inplace = True)

# %%
# Looks good now
scans2.head()
# Out:
#                      client             site        date control photoscan  \
# 0  independent-construction    russell-ranch  2018-07-03               NaN
# 1                 fivepoint  mission-village  2018-07-03               NaN
# 2  independent-construction          skyline  2018-07-05               NaN
# 3                   landsea        sanctuary  2018-07-03               NaN
# 4  independent-construction    river-islands  2018-07-05               NaN
#
#   accuracy cameras     camera model   resolution number of photos  \
# 0            10.00  FC350 (3.61 mm)  4000 x 3000              714
# 1            10.00  FC350 (3.61 mm)  4000 x 3000             2294
# 2            10.00  FC350 (3.61 mm)  4000 x 3000             1292
# 3                -  FC6310 (8.8 mm)  4864 x 3648              222
# 4                -  FC350 (3.61 mm)  4000 x 3000              944
#
#   Average camera location error, cm fact accuracy in photoscans,cm  \
# ...

# %%
# I convert 'date' columns to datetime format
scans['date'] = pd.to_datetime(scans['date'])

# %%
scans2['date'] = pd.to_datetime(scans2['date'])

# %%
# I am going to deal with string values in the rest of the columns later
scans.dtypes
# Out:
# client                                 object
# site                                   object
# date                           datetime64[ns]
# accuracy cameras. m                    object
# Number of images                       object
# Flying altitude                        object
# Ground resolution                      object
# Coverage area                          object
# Tie points                             object
# Projections                            object
# Camera Model                           object
# Resolution                             object
# Pixel Size                             object
# Precalibrated                          object
# Type                                   object
# Total (cm)                             object
# Matching time                          object
# Alignment time                         object
# X error (cm)                           object
# Y error (cm)                           object
# ...

# %%
# There's a weird 'Unnamed: 16' column with 50% of missing values
scans2.isnull().sum()
# Out:
# client                                96
# site                                  96
# date                                  96
# control photoscan                    267
# accuracy cameras                     110
# camera model                          96
# resolution                            96
# number of photos                      98
# Average camera location error, cm     96
# fact accuracy in photoscans,cm        96
# image overlap                        288
# fractional dem-diff                  333
# fractional dd colours                406
# volume control                       252
# monitoring area                      325
# result                               143
# Unnamed: 16                          438
# dtype: int64

# %%
# I'm just deleting it
scans2 = scans2.drop('Unnamed: 16', axis = 1)

# %%
# Time to merge two dataframes!
scans_fin = pd.merge(scans, scans2, how = 'inner')

# %%
# My final dataframe
scans_fin.head()
# Out:
#                      client             site       date accuracy cameras. m  \
# 0  independent-construction    russell-ranch 2018-07-03               10.00
# 1                 fivepoint  mission-village 2018-07-03               10.00
# 2  independent-construction          skyline 2018-07-05               10.00
# 3                   landsea        sanctuary 2018-07-03                   -
# 4  independent-construction    river-islands 2018-07-05                   -
#
#   Number of images Flying altitude Ground resolution Coverage area Tie points  \
# 0              714           167 m       7.11 cm/pix    0.924 km^2    1506410
# 1             2294           224 m       9.59 cm/pix     4.84 km^2    4208390
# 2             1292           254 m       11.1 cm/pix     2.36 km^2    2217947
# 3              222           125 m       3.59 cm/pix    0.315 km^2    1218819
# 4              944           146 m       6.13 cm/pix     1.68 km^2    3456900
#
# ...

# %%
#  I checked if the merge was performed correctly on three identical columns
scans.shape
# Out:
# (959, 39)

# %%
scans2.shape
# Out:
# (1055, 16)

# %%
# All good, the merge was a success
scans_fin.shape
# Out:
# (983, 52)

# %%
# I want to see all 52 columns on my screen
pd.set_option('display.max_columns', None)

# %%
# Our columns list -- this information is available for analysis. Well, almost available. 
scans_fin.columns
# Out:
# Index(['client', 'site', 'date', 'accuracy cameras. m', 'Number of images',
#        'Flying altitude', 'Ground resolution', 'Coverage area', 'Tie points',
#        'Projections', 'Camera Model', 'Resolution', 'Pixel Size',
#        'Precalibrated', 'Type', 'Total (cm)', 'Matching time',
#        'Alignment time', 'X error (cm)', 'Y error (cm)', 'Z error (cm)',
#        'XY error (cm)', 'Total (cm).1', 'Resolution.1', 'Point density',
#        'Coordinate system', 'Rotation angles', 'RMS reprojection error',
#        'Max reprojection error', 'Mean key point size', 'Effective overlap',
#        'Accuracy', 'Generic preselection', 'Reference preselection',
#        'Key point limit', 'Tie point limit', 'Optimization time',
#        'Depth maps generation time', 'Dense cloud generation time',
#        'control photoscan', 'accuracy cameras', 'camera model', 'resolution',
#        'number of photos', 'Average camera location error, cm',
# ...

# %%
scans_fin.isnull().sum()
# Out:
# client                                 0
# site                                   0
# date                                   0
# accuracy cameras. m                    0
# Number of images                       1
# Flying altitude                        0
# Ground resolution                      0
# Coverage area                          0
# Tie points                             0
# Projections                            0
# Camera Model                           0
# Resolution                             0
# Pixel Size                             0
# Precalibrated                          0
# Type                                   0
# Total (cm)                             0
# Matching time                          0
# Alignment time                         0
# X error (cm)                           1
# Y error (cm)                           0
# Z error (cm)                           0
# XY error (cm)                          0
# Total (cm).1                           0
# ...

# %%
# Some explorations: I noticed '-' value in this column. Needs to be converted to NaN
scans_fin['control photoscan'].value_counts()
# Out:
# good      715
# normal     82
# bad         4
# -           1
# Name: control photoscan, dtype: int64

# %%
# Boolean values in 'monitoring area', have to find out what it means
scans_fin['monitoring area'].value_counts()
# Out:
# True     371
# False    277
# Name: monitoring area, dtype: int64

# %%
# Getting some statistics about my final dataframe
scans_fin.describe()
# Out:
#                           client                                site  \
# count                        983                                 983
# unique                        30                                  80
# top     independent-construction  rmv-realty-inc-pa3-phase-1-grading
# freq                         250                                 105
# first                        NaN                                 NaN
# last                         NaN                                 NaN
#
#                        date accuracy cameras. m Number of images  \
# count                   983                 983              982
# unique                  524                   3              579
# top     2019-10-26 00:00:00                0.05                -
# freq                     11                 486               45
# first   1900-01-15 00:00:00                 NaN              NaN
# last    2020-06-11 00:00:00                 NaN              NaN
#
# ...

# %%
# Remember our '-'s? Those are missing values, we are replacing them with NaNs
scans_fin.replace('-', np.NaN, inplace=True)

# %%
# I believe this column can be converted to floats
scans_fin['accuracy cameras. m'].value_counts()
# Out:
# 0.05     486
# 10.00    267
# Name: accuracy cameras. m, dtype: int64

# %%
scans_fin['accuracy cameras. m'] = scans_fin['accuracy cameras. m'].astype(float)

# %%
scans_fin.head()
# Out:
#                      client             site       date  accuracy cameras. m  \
# 0  independent-construction    russell-ranch 2018-07-03                 10.0
# 1                 fivepoint  mission-village 2018-07-03                 10.0
# 2  independent-construction          skyline 2018-07-05                 10.0
# 3                   landsea        sanctuary 2018-07-03                  NaN
# 4  independent-construction    river-islands 2018-07-05                  NaN
#
#   Number of images Flying altitude Ground resolution Coverage area Tie points  \
# 0              714           167 m       7.11 cm/pix    0.924 km^2    1506410
# 1             2294           224 m       9.59 cm/pix     4.84 km^2    4208390
# 2             1292           254 m       11.1 cm/pix     2.36 km^2    2217947
# 3              222           125 m       3.59 cm/pix    0.315 km^2    1218819
# 4              944           146 m       6.13 cm/pix     1.68 km^2    3456900
#
# ...

# %%
# After close inspection I decided that columns below should be numeric

numeric_names = ['Number of images', 'Total (cm)', 'X error (cm)', 'Y error (cm)',  'Z error (cm)',
'Total (cm).1', 'Effective overlap', 'accuracy cameras', 'number of photos', 'Average camera location error, cm', 'fact accuracy in photoscans,cm', 'XY error (cm)']

# %%
for name in numeric_names:
    scans_fin[name] = scans_fin[name].astype(float)

# %%
# Value types look more balanced now, but the preparation work is far from being done
scans_fin.dtypes
# Out:
# client                                       object
# site                                         object
# date                                 datetime64[ns]
# accuracy cameras. m                         float64
# Number of images                            float64
# Flying altitude                              object
# Ground resolution                            object
# Coverage area                                object
# Tie points                                   object
# Projections                                  object
# Camera Model                                 object
# Resolution                                   object
# Pixel Size                                   object
# Precalibrated                                object
# Type                                         object
# Total (cm)                                  float64
# Matching time                                object
# Alignment time                               object
# ...

# %%
# I need to get rid of units definition in our values 
# This function leaves only numbers, dots and comas
for colname in ['Flying altitude','Ground resolution','Coverage area','Resolution.1','Point density','Mean key point size']:    
    scans_fin[colname] = scans_fin[colname].str.replace('[^0-9,.]','',regex=True ).astype("float")

# %%
# Some continuous numeric values are stored with coma separator -- we don't need that
for colname in ['Tie points','Projections']:    
    scans_fin[colname] = scans_fin[colname].astype(str).str.replace(',','',regex=True ).astype("float")

# %%
scans_fin.dtypes
# Out:
# client                                       object
# site                                         object
# date                                 datetime64[ns]
# accuracy cameras. m                         float64
# Number of images                            float64
# Flying altitude                             float64
# Ground resolution                           float64
# Coverage area                               float64
# Tie points                                  float64
# Projections                                 float64
# Camera Model                                 object
# Resolution                                   object
# Pixel Size                                   object
# Precalibrated                                object
# Type                                         object
# Total (cm)                                  float64
# Matching time                                object
# Alignment time                               object
# ...

# %%
# There are four columns containing time as process duration
# The information is stored in hours, minutes and seconds 
# I need to recalculate all those values in seconds
# The function below finds patterns and returns duration in seconds
import re
import math

def get_match(string,pattern):
    if not string != string:
        found = pattern.search(string)
        if found != None:
            value = re.compile("\d{1,}").search(found[0])
            return int(value[0])
    return 0 

def convert_time(col):
    
    for index, row in col.iteritems():
        min_p = re.compile("\d{1,}\sminutes")
        sec_p = re.compile("\d{1,}\sseconds")    
        hr_p = re.compile("\d{1,}\shours")    
        mins = get_match(row, min_p)
        secs = get_match(row, sec_p)
        hrs = get_match(row, hr_p)
        time = mins * 60 + secs + hrs * 60 * 60
        col[index] = time

time_columns = ['Matching time', 'Alignment time', 'Optimization time', 'Depth maps generation time', 'Dense cloud generation time']

for column in time_columns:
    convert_time(scans_fin[column])
    scans_fin[column] = scans_fin[column].astype("float")

# %%
scans_fin['result'].value_counts()
# Out:
# good          443
# acceptable    334
# visual        114
# bad            27
# deleted        12
# test            1
# Name: result, dtype: int64

# %%
# I delete columns that have hugely imbalanced data with just two uniques, and duplicating columns
scans_fin = scans_fin.drop(['Key point limit', 'Tie point limit', 'Precalibrated', 'camera model'], axis=1)

# %%
scans_fin.describe(include='all')
# Out:
#                           client                                site  \
# count                        983                                 983
# unique                        30                                  80
# top     independent-construction  rmv-realty-inc-pa3-phase-1-grading
# freq                         250                                 105
# first                        NaN                                 NaN
# last                         NaN                                 NaN
# mean                         NaN                                 NaN
# std                          NaN                                 NaN
# min                          NaN                                 NaN
# 25%                          NaN                                 NaN
# 50%                          NaN                                 NaN
# 75%                          NaN                                 NaN
# max                          NaN                                 NaN
#
# ...

# %%
# I drop columns that don't vary at all
cols = scans_fin.columns[scans_fin.nunique() <= 1]
scans_fin = scans_fin.drop(cols, axis = 1) 
scans_fin.head()
# Out:
#                      client             site       date  accuracy cameras. m  \
# 0  independent-construction    russell-ranch 2018-07-03                 10.0
# 1                 fivepoint  mission-village 2018-07-03                 10.0
# 2  independent-construction          skyline 2018-07-05                 10.0
# 3                   landsea        sanctuary 2018-07-03                  NaN
# 4  independent-construction    river-islands 2018-07-05                  NaN
#
#    Number of images  Flying altitude  Ground resolution  Coverage area  \
# 0             714.0            167.0               7.11         0.9242
# 1            2294.0            224.0               9.59         4.8420
# 2            1292.0            254.0              11.10         2.3620
# 3             222.0            125.0               3.59         0.3152
# 4             944.0            146.0               6.13         1.6820
#
#    Tie points  Projections     Camera Model   Resolution      Pixel Size  \
# ...

# %%
scans_fin.describe()
# Out:
#        accuracy cameras. m  Number of images  Flying altitude  \
# count           753.000000        937.000000       938.000000
# mean              3.578088        778.159018       130.467164
# std               4.763108        688.144356        37.433369
# min               0.050000         49.000000        19.700000
# 25%               0.050000        261.000000       105.000000
# 50%               0.050000        539.000000       133.000000
# 75%              10.000000       1145.000000       144.000000
# max              10.000000       4730.000000       304.000000
#
#        Ground resolution  Coverage area    Tie points   Projections  \
# count         938.000000     938.000000  9.380000e+02  9.380000e+02
# mean            4.162271       1.181217  2.522623e+06  1.145112e+07
# std             1.976450       1.838073  2.119419e+06  9.694174e+06
# min             1.070000       0.019120  1.985980e+05  5.928280e+05
# ...

# %%
# There are 44 columns left -- and I still feel like not all of them are valuable for prediction
scans_fin.shape
# Out:
# (983, 44)

# %%
# I have 18 categorical columns
scans_fin.select_dtypes('object').columns
# Out:
# Index(['client', 'site', 'Camera Model', 'Resolution', 'Pixel Size',
#        'Coordinate system', 'RMS reprojection error', 'Max reprojection error',
#        'Accuracy', 'control photoscan', 'resolution', 'image overlap',
#        'fractional dem-diff', 'fractional dd colours', 'volume control',
#        'monitoring area', 'result'],
#       dtype='object')

# %%
# How much missing data is there?
str_cols = [col for col in scans_fin.select_dtypes('object').columns
            if scans_fin[col].isnull().sum() < 100]

print(str_cols)
# Out:
# ['client', 'site', 'Camera Model', 'Resolution', 'Pixel Size', 'Coordinate system', 'RMS reprojection error', 'Max reprojection error', 'Accuracy', 'resolution', 'result']

# %%
# My strategy is to drop observations with NaNs
scans_fin = scans_fin.dropna()

# %%
# My dataset shrinked to a half of the initial size, but now I have complete observations with all characteristics
scans_fin.shape
# Out:
# (429, 44)

# %%
# No more missing values to worry about
scans_fin.isnull().sum()
# Out:
# client                               0
# site                                 0
# date                                 0
# accuracy cameras. m                  0
# Number of images                     0
# Flying altitude                      0
# Ground resolution                    0
# Coverage area                        0
# Tie points                           0
# Projections                          0
# Camera Model                         0
# Resolution                           0
# Pixel Size                           0
# Total (cm)                           0
# Matching time                        0
# Alignment time                       0
# X error (cm)                         0
# Y error (cm)                         0
# Z error (cm)                         0
# XY error (cm)                        0
# Total (cm).1                         0
# Resolution.1                         0
# Point density                        0
# Coordinate system                    0
# ...

# %%
# These are my numeric columns
scans_fin.select_dtypes('number').columns
# Out:
# Index(['accuracy cameras. m', 'Number of images', 'Flying altitude',
#        'Ground resolution', 'Coverage area', 'Tie points', 'Projections',
#        'Total (cm)', 'Matching time', 'Alignment time', 'X error (cm)',
#        'Y error (cm)', 'Z error (cm)', 'XY error (cm)', 'Total (cm).1',
#        'Resolution.1', 'Point density', 'Mean key point size',
#        'Effective overlap', 'Optimization time', 'Depth maps generation time',
#        'Dense cloud generation time', 'accuracy cameras', 'number of photos',
#        'Average camera location error, cm', 'fact accuracy in photoscans,cm'],
#       dtype='object')

# %%
# I want to sort my observations by date
scans_fin = scans_fin.sort_values(by=['date'])

# %%
# 'result' column is what we are going to predict
scans_fin['result'].value_counts()
# Out:
# good          261
# acceptable    146
# visual         21
# bad             1
# Name: result, dtype: int64

# %%
# Business logic tells us that visual and bad categories fall beyond acceptance, 
# So we can consider those scans to be bad
scans_fin['result'] = scans_fin['result'].map({'good': 'good', 'acceptable': 'acceptable', 'bad':'bad', 'visual':'bad'})

# %%
# Looks like we have our target, ladies and gents
scans_fin['result'].value_counts()
# Out:
# good          261
# acceptable    146
# bad            22
# Name: result, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='result',data=scans_fin)

# %%
sns.catplot(x="result", y="Effective overlap", kind="swarm", data=scans_fin);

# %%
sns.catplot(x="result", y="Alignment time", data=scans_fin);

# %%
sns.catplot(x="result", y="Flying altitude", hue="Camera Model", kind="swarm", data=scans_fin);

# %%
sns.catplot(x="result", y="Z error (cm)", hue="image overlap", kind="bar", data=scans_fin);

# %%
# Defining my baseline: 
# Majority class happens in 60% of times -- meaning the scan is good
scans_fin['result'].value_counts(normalize=True)
# Out:
# good          0.608392
# acceptable    0.340326
# bad           0.051282
# Name: result, dtype: float64

# %%
# 
from sklearn.model_selection import train_test_split

# %%
target = 'result'

# %%
# I group my data by year to split train, validation and test accordingly
scans_fin.groupby(scans_fin.date.dt.year).describe()
# Out:
# 2925  1.58
#
#                                   Coverage area                               \
#          25%    50%     75%   max         count      mean       std      min
# date
# 2001  2.4650  2.490  2.6050  2.85          19.0  0.182785  0.118126  0.07032
# 2002  2.4675  2.580  2.6950  3.21          12.0  0.173260  0.109375  0.09892
# 2003  2.4225  2.445  2.6075  3.05           4.0  0.113700  0.003873  0.10820
# 2004  2.5700  2.600  2.6700  2.84           5.0  0.116600  0.007733  0.10720
# 2005  2.5000  2.500  2.5000  2.50           1.0  0.102200       NaN  0.10220
# 2019  3.5125  3.720  4.1300  6.89         250.0  1.292512  1.805805  0.02072
# 2020  2.2000  2.985  3.6400  9.94         138.0  0.543768  0.659118  0.02932
#
#                                        Tie points                              \
#           25%     50%      75%     max      count          mean           std
# date
# 2001  0.11420  0.1232  0.21720  0.4752       19.0  1.399695e+06  8.175187e+05
# ...

# %%
test = scans_fin[scans_fin.date >='2020-05-01']

# %%
val = scans_fin[scans_fin.date.between('2020-02-01', '2020-05-01', inclusive=False)]

# %%
train = scans_fin[scans_fin.date <'2020-02-01']

# %%
train.shape, val.shape, test.shape
# Out:
# ((312, 44), (59, 44), (55, 44))

# %%
# Now we can drop identification columns
train = train.drop(['client', 'site', 'date'], axis = 1)
val = val.drop(['client', 'site', 'date'], axis = 1)
test = test.drop(['client', 'site', 'date'], axis = 1)

# %%
# Arranging data to feature matrix and target vector
X_train = train.drop(columns=target)
y_train = train[target]
X_val = val.drop(columns=target)
y_val = val[target]
X_test = test.drop(columns=target)
y_test = test[target]

# %%
X_train.columns
# Out:
# Index(['accuracy cameras. m', 'Number of images', 'Flying altitude',
#        'Ground resolution', 'Coverage area', 'Tie points', 'Projections',
#        'Camera Model', 'Resolution', 'Pixel Size', 'Total (cm)',
#        'Matching time', 'Alignment time', 'X error (cm)', 'Y error (cm)',
#        'Z error (cm)', 'XY error (cm)', 'Total (cm).1', 'Resolution.1',
#        'Point density', 'Coordinate system', 'RMS reprojection error',
#        'Max reprojection error', 'Mean key point size', 'Effective overlap',
#        'Accuracy', 'Optimization time', 'Depth maps generation time',
#        'Dense cloud generation time', 'control photoscan', 'accuracy cameras',
#        'resolution', 'number of photos', 'Average camera location error, cm',
#        'fact accuracy in photoscans,cm', 'image overlap',
#        'fractional dem-diff', 'fractional dd colours', 'volume control',
#        'monitoring area'],
#       dtype='object')

# %%
# %matplotlib inline
import category_encoders as ce
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer
from sklearn.tree import DecisionTreeClassifier

# %%
# Let's fit a linear model and see if we can beat our baseline
log_pipeline = make_pipeline(ce.OneHotEncoder(),
                             
                        
                            LogisticRegression(max_iter=200))
log_pipeline.fit(X_train, y_train);
print('Logistic Regression Train Accuracy:', log_pipeline.score(X_train, y_train))
print('Logistic Regression Validation Accuracy:', log_pipeline.score(X_val, y_val))
# Out:
# Logistic Regression Train Accuracy: 0.5544871794871795
# Logistic Regression Validation Accuracy: 0.6779661016949152

# %%
# Not a spectacula performance by Logistic Regression, and yet we managed to beat the baseline
print('Logistic Regression Test Accuracy:', log_pipeline.score(X_test, y_test))
# Out:
# Logistic Regression Test Accuracy: 0.6727272727272727

# %%
# Let's try our luck with Random Forest with best parameters search
from scipy.stats import uniform
from sklearn.model_selection import RandomizedSearchCV


pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
   
    RandomForestClassifier(random_state=42)
)

param_distributions = {
    'randomforestclassifier__n_estimators': range(50, 500), 
    'randomforestclassifier__max_depth': [5, 10, 15, 20, None], 
    'randomforestclassifier__max_features': uniform(0, 1), 
    'randomforestclassifier__min_samples_leaf': [1, 10, 100], 
}

search = RandomizedSearchCV(
    pipeline, 
    param_distributions=param_distributions, 
    n_iter=10, 
    cv=3, 
    scoring='accuracy', 
    verbose=10, 
    return_train_score=True, 
    n_jobs=-1
)

search.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  11 out of  30 | elapsed:    3.4s remaining:    6.0s
# [Parallel(n_jobs=-1)]: Done  15 out of  30 | elapsed:    3.6s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  19 out of  30 | elapsed:    4.1s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done  23 out of  30 | elapsed:    4.2s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  27 out of  30 | elapsed:    4.4s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    4.6s finished

# %%
# This looks like overfit 
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_train)
print('Random Forest train accuracy', accuracy_score(y_train, y_pred))
# Out:
# Random Forest train accuracy 1.0

# %%
# Both train and validation accuracy tell us that this model is troubled
pipeline.fit(X_val, y_val)
y_pred = pipeline.predict(X_val)
print('Random Forest validation accuracy', accuracy_score(y_val, y_pred))
# Out:
# Random Forest validation accuracy 1.0

# %%
# Test accuracy is no higher than Logistic Regression model (still beating our baseline, though)
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
print('Random Forest test accuracy', accuracy_score(y_test, y_pred))
# Out:
# Random Forest test accuracy 0.6545454545454545

# %%
# Let's try another Random Forest, using just one hyperparameter that's not default
pipeline2 = make_pipeline(
    ce.OneHotEncoder(), 
  
    RandomForestClassifier(n_estimators=30, 
                           random_state=42, 
                           n_jobs=-1)
)

# Fit on train, score on val
pipeline2.fit(X_train, y_train);pipeline2 = make_pipeline(
    ce.OrdinalEncoder(), 

    RandomForestClassifier(n_estimators=30, 
                           random_state=42, 
                           n_jobs=-1)
)

# Fit on train, score on val
pipeline2.fit(X_train, y_train);

# %%
print('RF 2 Training Accuracy:', pipeline2.score(X_train, y_train))
print('RF 2 Validation Accuracy:', pipeline2.score(X_val, y_val))
# Out:
# RF 2 Training Accuracy: 0.9967948717948718
# RF 2 Validation Accuracy: 0.5423728813559322

# %%
# This model performs better on test 
pipeline2.fit(X_train, y_train)
y_pred = pipeline2.predict(X_test)
print('RF 2 Test accuracy2', accuracy_score(y_test, y_pred))
# Out:
# RF 2 Test accuracy2 0.7090909090909091

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# How about Gradient Boosting?
pipeline3 = make_pipeline(
    ce.OrdinalEncoder(), 
   
    GradientBoostingClassifier(random_state=42)
)

pipeline3.fit(X_train, y_train);

# %%
print('GB Training Accuracy:', pipeline3.score(X_train, y_train))
print('GB Validation Accuracy:', pipeline3.score(X_val, y_val))
# Out:
# GB Training Accuracy: 0.9967948717948718
# GB Validation Accuracy: 0.5423728813559322

# %%
# This attempt fails
pipeline3.fit(X_train, y_train)
y_pred = pipeline3.predict(X_test)
print('GB Test accuracy3', accuracy_score(y_test, y_pred))
# Out:
# GB Test accuracy3 0.32727272727272727

# %%
from xgboost import XGBClassifier

# %%
# Trying my luck with XGB Classifier
pipeline4 = make_pipeline(
    ce.OneHotEncoder(),
    XGBClassifier(n_estimators=100
    ,
                  random_state=42,
                  n_jobs=-1)
)

pipeline4.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('onehotencoder',
#                  OneHotEncoder(cols=['Camera Model', 'Resolution', 'Pixel Size',
#                                      'Coordinate system',
#                                      'RMS reprojection error',
#                                      'Max reprojection error', 'Accuracy',
#                                      'control photoscan', 'resolution',
#                                      'image overlap', 'fractional dem-diff',
#                                      'fractional dd colours', 'volume control',
#                                      'monitoring area'])),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster=No...
#                                interaction_constraints=None,
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
# ...

# %%
print(' XGB Training Accuracy:', pipeline4.score(X_train, y_train))
print('XGB Validation Accuracy:', pipeline4.score(X_val, y_val))
# Out:
# XGB Training Accuracy: 1.0
# XGB Validation Accuracy: 0.6949152542372882

# %%
# This model's test accuracy gives me some hope for decent prediction of scan quality
pipeline4.fit(X_train, y_train)
y_pred = pipeline4.predict(X_test)
print('XGB test accuracy4', accuracy_score(y_test, y_pred))
# Out:
# XGB test accuracy4 0.8

# %%
# Going back to my Random Forest model to look at feature importances
rf = pipeline.named_steps['randomforestclassifier']
importances = pd.Series(rf.feature_importances_, X_train.columns)

# Plot feature importances
# %matplotlib inline
import matplotlib.pyplot as plt

n = 30
plt.figure(figsize=(10,n/2))
plt.title(f'Top {n} features')
importances.sort_values()[-n:].plot.barh(color='grey');

# %%
# Confusion matrix visualization
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(pipeline, X_val, y_val, values_format='.0f', xticks_rotation='vertical');

# %%
column  = 'Camera Model'

# Fit without column
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
   
    RandomForestClassifier(n_estimators=20, random_state=42, n_jobs=-1)
)
pipeline.fit(X_train.drop(columns=column), y_train)
score_without = pipeline.score(X_val.drop(columns=column), y_val)
print(f'Validation Accuracy without {column}: {score_without}')

# Fit with column
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
   
    RandomForestClassifier(n_estimators=20, random_state=42, n_jobs=-1)
)
pipeline.fit(X_train, y_train)
score_with = pipeline.score(X_val, y_val)
print(f'Validation Accuracy with {column}: {score_with}')

# Compare the error with & without column
print(f'Drop-Column Importance for {column}: {score_with - score_without}')
# Out:
# Validation Accuracy without Camera Model: 0.4745762711864407
# Validation Accuracy with Camera Model: 0.4745762711864407
# Drop-Column Importance for Camera Model: 0.0

# %%
column  = 'volume control'

# Fit without column
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
   
    RandomForestClassifier(n_estimators=30, random_state=42, n_jobs=-1)
)
pipeline.fit(X_train.drop(columns=column), y_train)
score_without = pipeline.score(X_val.drop(columns=column), y_val)
print(f'Validation Accuracy without {column}: {score_without}')

# Fit with column
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
   
    RandomForestClassifier(n_estimators=30, random_state=42, n_jobs=-1)
)
pipeline.fit(X_train, y_train)
score_with = pipeline.score(X_val, y_val)
print(f'Validation Accuracy with {column}: {score_with}')

# Compare the error with & without column
print(f'Drop-Column Importance for {column}: {score_with - score_without}')
# Out:
# Validation Accuracy without volume control: 0.5423728813559322
# Validation Accuracy with volume control: 0.5423728813559322
# Drop-Column Importance for volume control: 0.0

# %%
from sklearn.inspection import permutation_importance

pi = permutation_importance(pipeline,
                            X_val,
                            y_val,
                            random_state=42,
                            n_jobs=-1)

# %%
pi.keys()
# Out:
# dict_keys(['importances_mean', 'importances_std', 'importances'])

# %%
p_importance = pd.DataFrame({'feature' : X_val.columns,
                             'weight'  : pi.importances_mean,
                             'std'     : pi.importances_std})

p_importance.sort_values('weight', ascending=False).tail(10)
# Out:
#                            feature    weight       std
# 39                 monitoring area -0.003390  0.006780
# 16                   XY error (cm) -0.006780  0.013559
# 10                      Total (cm) -0.010169  0.013559
# 38                  volume control -0.010169  0.008303
# 13                    X error (cm) -0.013559  0.006780
# 19                   Point density -0.013559  0.012684
# 15                    Z error (cm) -0.013559  0.027119
# 28     Dense cloud generation time -0.016949  0.015160
# 34  fact accuracy in photoscans,cm -0.020339  0.019766
# 1                 Number of images -0.027119  0.017285

# %%
for col in X_train:

    pipeline = make_pipeline(
        ce.OrdinalEncoder(), 
    
        RandomForestClassifier(n_estimators=30, random_state=42, n_jobs=-1)
    )
    pipeline.fit(X_train.drop(columns=col), y_train)
    score_without = pipeline.score(X_val.drop(columns=col), y_val)
    print(f'Validation Accuracy without {col}: {score_without}')

    # Fit with column
    pipeline = make_pipeline(
        ce.OrdinalEncoder(), 
    
        RandomForestClassifier(n_estimators=30, random_state=42, n_jobs=-1)
    )
    pipeline.fit(X_train, y_train)
    score_with = pipeline.score(X_val, y_val)
    print(f'Validation Accuracy with {col}: {score_with}')

    # Compare the error with & without column
    print(f'Drop-Column Importance for {col}: {score_with - score_without}')
# Out:
# Validation Accuracy without accuracy cameras. m: 0.559322033898305
# Validation Accuracy with accuracy cameras. m: 0.5423728813559322
# Drop-Column Importance for accuracy cameras. m: -0.016949152542372836
# Validation Accuracy without Number of images: 0.4915254237288136
# Validation Accuracy with Number of images: 0.5423728813559322
# Drop-Column Importance for Number of images: 0.05084745762711862
# Validation Accuracy without Flying altitude: 0.559322033898305
# Validation Accuracy with Flying altitude: 0.5423728813559322
# Drop-Column Importance for Flying altitude: -0.016949152542372836
# Validation Accuracy without Ground resolution: 0.5254237288135594
# Validation Accuracy with Ground resolution: 0.5423728813559322
# Drop-Column Importance for Ground resolution: 0.016949152542372836
# Validation Accuracy without Coverage area: 0.4745762711864407
# Validation Accuracy with Coverage area: 0.5423728813559322
# Drop-Column Importance for Coverage area: 0.06779661016949151
# ...

# %%
X_train_best = X_train.drop(['Number of images'], axis =1)
X_train_best.shape
# Out:
# (312, 39)

# %%
X_test_best = X_test.drop(['Number of images'], axis =1)

# %%
pipeline_best = make_pipeline(
    ce.OrdinalEncoder(), 
   
    RandomForestClassifier(random_state=42)
)

param_distributions = {
    'randomforestclassifier__n_estimators': range(50, 500), 
    'randomforestclassifier__max_depth': [5, 10, 15, 20, None], 
    'randomforestclassifier__max_features': uniform(0, 1), 
    'randomforestclassifier__min_samples_leaf': [1, 10, 100], 
}

search = RandomizedSearchCV(
    pipeline_best, 
    param_distributions=param_distributions, 
    n_iter=10, 
    cv=3, 
    scoring='accuracy', 
    verbose=10, 
    return_train_score=True, 
    n_jobs=-1
)

search.fit(X_train_best, y_train);
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  11 out of  30 | elapsed:    2.4s remaining:    4.1s
# [Parallel(n_jobs=-1)]: Done  15 out of  30 | elapsed:    2.6s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  19 out of  30 | elapsed:    2.8s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  23 out of  30 | elapsed:    3.0s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  27 out of  30 | elapsed:    3.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    3.9s finished

# %%
pipeline_best.fit(X_train_best, y_train)
y_pred_best = pipeline_best.predict(X_test_best)
print('test accuracy', accuracy_score(y_test, y_pred_best))
# Out:
# test accuracy 0.8181818181818182

# %%
X_val_best = X_val.drop(['Number of images'], axis =1)

# %%
y_pred_best = pipeline_best.predict(X_val_best)

# %%
print('val accuracy', accuracy_score(y_val, y_pred_best))
# Out:
# val accuracy 0.6440677966101694

# %%
# Export column names we are not writing in 40 columns manually
newdf = pd.DataFrame() 

for col,coldata in X_train_best.select_dtypes(exclude=np.number).iteritems():
    newdf[col] = pd.Series(X_train_best[col].unique())

for col,coldata in X_train_best.select_dtypes(include=np.number).iteritems():
    newdf[col] = pd.Series([X_train_best[col].min(),X_train_best[col].max()])


newdf.to_csv("column_values.csv",index=False)

# dump the model into joblib file
import joblib

joblib.dump(pipeline_best, "model_best.joblib")
# Out:
# ['model_best.joblib']

# %%
# Just from a pure curiousity I want to try visualizing one prediction explanation

import shap
from scipy.stats import randint, uniform
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

enc = ce.OneHotEncoder()

y_train_trans = enc.fit_transform(y_train)

param_distributions = { 
    'n_estimators': randint(50, 500), 
    'max_depth': [5, 10, 15, 20, None], 
    'max_features': uniform(0, 1), 
}
search2 = RandomizedSearchCV(
    RandomForestRegressor(random_state=42), 
    param_distributions=param_distributions, 
    n_iter=5, 
    cv=2, 
    scoring='neg_mean_absolute_error', 
    verbose=10, 
    return_train_score=True, 
    n_jobs=-1, 
    random_state=42
)
enc = ce.OneHotEncoder()

X_train_trans = enc.fit_transform(X_train_best)
search2.fit(X_train_trans, y_train_trans);
row = X_train_trans.iloc[0]



model2 = search2.best_estimator_


explainer = shap.TreeExplainer(model2)
shap_values = explainer.shap_values(row)

shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value[0],
    shap_values=shap_values[0],
    features=row
)
# Out:
# Fitting 2 folds for each of 5 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    2.3s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    2.4s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    2.5s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    2.5s finished
# ...
